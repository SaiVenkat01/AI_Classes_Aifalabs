# %%
# !pip install sentence-transformers
# Out:
# Collecting sentence-transformers
#   Downloading sentence_transformers-4.1.0-py3-none-any.whl (345 kB)
# Requirement already satisfied: typing_extensions>=4.5.0 in d:\visual studio code\ai_classes_aifalabs\.venv\lib\site-packages (from sentence-transformers) (4.13.2)
# Requirement already satisfied: tqdm in d:\visual studio code\ai_classes_aifalabs\.venv\lib\site-packages (from sentence-transformers) (4.67.1)
# Requirement already satisfied: scikit-learn in d:\visual studio code\ai_classes_aifalabs\.venv\lib\site-packages (from sentence-transformers) (1.6.1)
# Requirement already satisfied: Pillow in d:\visual studio code\ai_classes_aifalabs\.venv\lib\site-packages (from sentence-transformers) (11.2.1)
# Requirement already satisfied: scipy in d:\visual studio code\ai_classes_aifalabs\.venv\lib\site-packages (from sentence-transformers) (1.15.3)
# Collecting transformers<5.0.0,>=4.41.0
#   Downloading transformers-4.52.4-py3-none-any.whl (10.5 MB)
# Collecting torch>=1.11.0
#   Downloading torch-2.7.1-cp310-cp310-win_amd64.whl (216.1 MB)
# Collecting huggingface-hub>=0.20.0
#   Downloading huggingface_hub-0.32.4-py3-none-any.whl (512 kB)
# Collecting filelock
#   Downloading filelock-3.18.0-py3-none-any.whl (16 kB)
# Requirement already satisfied: pyyaml>=5.1 in d:\visual studio code\ai_classes_aifalabs\.venv\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (6.0.2)
# Requirement already satisfied: requests in d:\visual studio code\ai_classes_aifalabs\.venv\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2.32.3)
# Collecting fsspec>=2023.5.0
#   Downloading fsspec-2025.5.1-py3-none-any.whl (199 kB)
# Requirement already satisfied: packaging>=20.9 in d:\visual studio code\ai_classes_aifalabs\.venv\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (24.2)
# Collecting sympy>=1.13.3
#   Downloading sympy-1.14.0-py3-none-any.whl (6.3 MB)
# Collecting jinja2
#   Downloading jinja2-3.1.6-py3-none-any.whl (134 kB)
# Collecting networkx
#   Using cached networkx-3.4.2-py3-none-any.whl (1.7 MB)
# Collecting mpmath<1.4,>=1.1.0
#   Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# Requirement already satisfied: colorama in d:\visual studio code\ai_classes_aifalabs\.venv\lib\site-packages (from tqdm->sentence-transformers) (0.4.6)
# Requirement already satisfied: regex!=2019.12.17 in d:\visual studio code\ai_classes_aifalabs\.venv\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2024.11.6)
# Requirement already satisfied: numpy>=1.17 in d:\visual studio code\ai_classes_aifalabs\.venv\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2.1.3)
# Collecting tokenizers<0.22,>=0.21
#   Downloading tokenizers-0.21.1-cp39-abi3-win_amd64.whl (2.4 MB)
# Collecting safetensors>=0.4.3
#   Downloading safetensors-0.5.3-cp38-abi3-win_amd64.whl (308 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\visual studio code\ai_classes_aifalabs\.venv\lib\site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.2)
# Requirement already satisfied: certifi>=2017.4.17 in d:\visual studio code\ai_classes_aifalabs\.venv\lib\site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2025.4.26)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\visual studio code\ai_classes_aifalabs\.venv\lib\site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\visual studio code\ai_classes_aifalabs\.venv\lib\site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2.4.0)
# Requirement already satisfied: idna<4,>=2.5 in d:\visual studio code\ai_classes_aifalabs\.venv\lib\site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (3.10)
# Requirement already satisfied: threadpoolctl>=3.1.0 in d:\visual studio code\ai_classes_aifalabs\.venv\lib\site-packages (from scikit-learn->sentence-transformers) (3.6.0)
# Requirement already satisfied: joblib>=1.2.0 in d:\visual studio code\ai_classes_aifalabs\.venv\lib\site-packages (from scikit-learn->sentence-transformers) (1.5.1)
# Installing collected packages: fsspec, filelock, mpmath, huggingface-hub, tokenizers, sympy, safetensors, networkx, jinja2, transformers, torch, sentence-transformers
# Successfully installed filelock-3.18.0 fsspec-2025.5.1 huggingface-hub-0.32.4 jinja2-3.1.6 mpmath-1.3.0 networkx-3.4.2 safetensors-0.5.3 sentence-transformers-4.1.0 sympy-1.14.0 tokenizers-0.21.1 torch-2.7.1 transformers-4.52.4
# WARNING: You are using pip version 21.2.4; however, version 25.1.1 is available.
# You should consider upgrading via the 'D:\Visual Studio Code\AI_Classes_Aifalabs\.venv\Scripts\python.exe -m pip install --upgrade pip' command.

# %% [markdown]
# # Data Ingestion

# %%
from langchain.document_loaders import PyMuPDFLoader
# Load the PDF
loader = PyMuPDFLoader("data/RAMAYANA.pdf")
docs = loader.load()

# Each doc now contains `page_content` and `metadata`
for doc in docs:
    print(doc.page_content[:200])  # Preview text
    print(doc.metadata)            # {'source': 'data/ramayana.pdf', 'page': 0}
# Out:
# SRI RAMA JAYAM
# RAMAYANA FOR CHILDREN
# Compiled by
#
# Visalakshi Gopalan
# 14-Apr-13
#
#
#
# For children’s reading
# {'producer': 'Microsoft® Word 2010', 'creator': 'Microsoft® Word 2010', 'creationdate': '2013-04-14T19:39:50-07:00', 'source': 'data/RAMAYANA.pdf', 'file_path': 'data/RAMAYANA.pdf', 'total_pages': 45, 'format': 'PDF 1.5', 'title': 'RAMAYANA FOR CHILDREN', 'author': 'Sony', 'subject': 'Compiled by', 'keywords': '', 'moddate': '2013-04-14T19:39:50-07:00', 'trapped': '', 'modDate': "D:20130414193950-07'00'", 'creationDate': "D:20130414193950-07'00'", 'page': 0}
# 1
#
# Contents
#
# 1 RAMAYANA FOR CHILDREN ............................................................................................... 2
# 1.1 THE BIRTH OF RAMA ......................................
# {'producer': 'Microsoft® Word 2010', 'creator': 'Microsoft® Word 2010', 'creationdate': '2013-04-14T19:39:50-07:00', 'source': 'data/RAMAYANA.pdf', 'file_path': 'data/RAMAYANA.pdf', 'total_pages': 45, 'format': 'PDF 1.5', 'title': 'RAMAYANA FOR CHILDREN', 'author': 'Sony', 'subject': 'Compiled by', 'keywords': '', 'moddate': '2013-04-14T19:39:50-07:00', 'trapped': '', 'modDate': "D:20130414193950-07'00'", 'creationDate': "D:20130414193950-07'00'", 'page': 1}
# 2
#
# 1 RAMAYANA FOR CHILDREN
#
# 1.1 THE BIRTH OF RAMA
#
# Ayodhya was a magnificent city on the banks of the river Sarayu in
# Kosala Country .It had wide roads, huge buildings, beautiful parks
# and gli
# {'producer': 'Microsoft® Word 2010', 'creator': 'Microsoft® Word 2010', 'creationdate': '2013-04-14T19:39:50-07:00', 'source': 'data/RAMAYANA.pdf', 'file_path': 'data/RAMAYANA.pdf', 'total_pages': 45, 'format': 'PDF 1.5', 'title': 'RAMAYANA FOR CHILDREN', 'author': 'Sony', 'subject': 'Compiled by', 'keywords': '', 'moddate': '2013-04-14T19:39:50-07:00', 'trapped': '', 'modDate': "D:20130414193950-07'00'", 'creationDate': "D:20130414193950-07'00'", 'page': 2}
# 3
#
# 1.2 The Valiant Princes
#
# The four princes grew up to be strong and handsome. Under sage
# Vashistha's guidance, they excelled themselves in archery, riding
# and hunting. They also learnt about t
# {'producer': 'Microsoft® Word 2010', 'creator': 'Microsoft® Word 2010', 'creationdate': '2013-04-14T19:39:50-07:00', 'source': 'data/RAMAYANA.pdf', 'file_path': 'data/RAMAYANA.pdf', 'total_pages': 45, 'format': 'PDF 1.5', 'title': 'RAMAYANA FOR CHILDREN', 'author': 'Sony', 'subject': 'Compiled by', 'keywords': '', 'moddate': '2013-04-14T19:39:50-07:00', 'trapped': '', 'modDate': "D:20130414193950-07'00'", 'creationDate': "D:20130414193950-07'00'", 'page': 3}
# 4
#
# because he himself is very powerful. He wants to take Rama with
# him so that your son can learn to fight the Rakshasas even at this
# young age. Send Rama with him."
#
# Without any more hesitatio
# {'producer': 'Microsoft® Word 2010', 'creator': 'Microsoft® Word 2010', 'creationdate': '2013-04-14T19:39:50-07:00', 'source': 'data/RAMAYANA.pdf', 'file_path': 'data/RAMAYANA.pdf', 'total_pages': 45, 'format': 'PDF 1.5', 'title': 'RAMAYANA FOR CHILDREN', 'author': 'Sony', 'subject': 'Compiled by', 'keywords': '', 'moddate': '2013-04-14T19:39:50-07:00', 'trapped': '', 'modDate': "D:20130414193950-07'00'", 'creationDate': "D:20130414193950-07'00'", 'page': 4}
# 5
#
# needed to lug it. Sage Vishwamitra knew about this bow and had
# purposely taken the young princes to Mithila.
#
# On their way to Mithila, they halted at an Ashram where Gautama, a
# sage, had once
# {'producer': 'Microsoft® Word 2010', 'creator': 'Microsoft® Word 2010', 'creationdate': '2013-04-14T19:39:50-07:00', 'source': 'data/RAMAYANA.pdf', 'file_path': 'data/RAMAYANA.pdf', 'total_pages': 45, 'format': 'PDF 1.5', 'title': 'RAMAYANA FOR CHILDREN', 'author': 'Sony', 'subject': 'Compiled by', 'keywords': '', 'moddate': '2013-04-14T19:39:50-07:00', 'trapped': '', 'modDate': "D:20130414193950-07'00'", 'creationDate': "D:20130414193950-07'00'", 'page': 5}
# 6
#
# for Rama, Lakshmana and Vishwamitra, everybody else turned pale.
# Ram, a lifted the entire bow like a toy and broke it into two. King
# Janaka was extremely happy that Rama, the eldest prince of
#
# {'producer': 'Microsoft® Word 2010', 'creator': 'Microsoft® Word 2010', 'creationdate': '2013-04-14T19:39:50-07:00', 'source': 'data/RAMAYANA.pdf', 'file_path': 'data/RAMAYANA.pdf', 'total_pages': 45, 'format': 'PDF 1.5', 'title': 'RAMAYANA FOR CHILDREN', 'author': 'Sony', 'subject': 'Compiled by', 'keywords': '', 'moddate': '2013-04-14T19:39:50-07:00', 'trapped': '', 'modDate': "D:20130414193950-07'00'", 'creationDate': "D:20130414193950-07'00'", 'page': 6}
# 7
#
# it”. Dasahratha who was watching Parushurama, came running to
# him and prayed to him "Parushurama, please calm down. My
# children have not done any harm to you. Bless them. Spare Rama".
# Parushur
# {'producer': 'Microsoft® Word 2010', 'creator': 'Microsoft® Word 2010', 'creationdate': '2013-04-14T19:39:50-07:00', 'source': 'data/RAMAYANA.pdf', 'file_path': 'data/RAMAYANA.pdf', 'total_pages': 45, 'format': 'PDF 1.5', 'title': 'RAMAYANA FOR CHILDREN', 'author': 'Sony', 'subject': 'Compiled by', 'keywords': '', 'moddate': '2013-04-14T19:39:50-07:00', 'trapped': '', 'modDate': "D:20130414193950-07'00'", 'creationDate': "D:20130414193950-07'00'", 'page': 7}
# 8
#
# invited to the city to provide entertainment to the people. The chiefs
# of the city were instructed to decorate it on a very grand scale. Even
# while these preparations were going on. Dasahratha
# {'producer': 'Microsoft® Word 2010', 'creator': 'Microsoft® Word 2010', 'creationdate': '2013-04-14T19:39:50-07:00', 'source': 'data/RAMAYANA.pdf', 'file_path': 'data/RAMAYANA.pdf', 'total_pages': 45, 'format': 'PDF 1.5', 'title': 'RAMAYANA FOR CHILDREN', 'author': 'Sony', 'subject': 'Compiled by', 'keywords': '', 'moddate': '2013-04-14T19:39:50-07:00', 'trapped': '', 'modDate': "D:20130414193950-07'00'", 'creationDate': "D:20130414193950-07'00'", 'page': 8}
# 9
#
# Provoked by Manthara, Kaikeyi thought about what she said. No, she
# did not mind Rama being the king. But could she, the favorite wife of
# Dasahratha, be a slave to Kaushalya? “Never” decided Kai
# {'producer': 'Microsoft® Word 2010', 'creator': 'Microsoft® Word 2010', 'creationdate': '2013-04-14T19:39:50-07:00', 'source': 'data/RAMAYANA.pdf', 'file_path': 'data/RAMAYANA.pdf', 'total_pages': 45, 'format': 'PDF 1.5', 'title': 'RAMAYANA FOR CHILDREN', 'author': 'Sony', 'subject': 'Compiled by', 'keywords': '', 'moddate': '2013-04-14T19:39:50-07:00', 'trapped': '', 'modDate': "D:20130414193950-07'00'", 'creationDate': "D:20130414193950-07'00'", 'page': 9}
# 10
#
# live in the forest like a hermit for fourteen years. Grant me these
# wishes right now. Otherwise, I will end my life.”
# King Dasharatha could not believe his own ears. He was horrified
# that Kai
# {'producer': 'Microsoft® Word 2010', 'creator': 'Microsoft® Word 2010', 'creationdate': '2013-04-14T19:39:50-07:00', 'source': 'data/RAMAYANA.pdf', 'file_path': 'data/RAMAYANA.pdf', 'total_pages': 45, 'format': 'PDF 1.5', 'title': 'RAMAYANA FOR CHILDREN', 'author': 'Sony', 'subject': 'Compiled by', 'keywords': '', 'moddate': '2013-04-14T19:39:50-07:00', 'trapped': '', 'modDate': "D:20130414193950-07'00'", 'creationDate': "D:20130414193950-07'00'", 'page': 10}
# 11
#
# told that the king was in Kaikeyi chamber, reached the room, only to
# find the king in a sad state. Kaikeyi stopped him from talking to the
# king and ordered him “Sumatra, go and fetch Rama here
# {'producer': 'Microsoft® Word 2010', 'creator': 'Microsoft® Word 2010', 'creationdate': '2013-04-14T19:39:50-07:00', 'source': 'data/RAMAYANA.pdf', 'file_path': 'data/RAMAYANA.pdf', 'total_pages': 45, 'format': 'PDF 1.5', 'title': 'RAMAYANA FOR CHILDREN', 'author': 'Sony', 'subject': 'Compiled by', 'keywords': '', 'moddate': '2013-04-14T19:39:50-07:00', 'trapped': '', 'modDate': "D:20130414193950-07'00'", 'creationDate': "D:20130414193950-07'00'", 'page': 11}
# 12
#
# Rama to the forest? Is she afraid of Bharatha? In that case, I will
# wipe out Bharatha and his supporters. “he shouted in anger. But
# Rama Spoke in a calm and firm voice that it was his duty to
# {'producer': 'Microsoft® Word 2010', 'creator': 'Microsoft® Word 2010', 'creationdate': '2013-04-14T19:39:50-07:00', 'source': 'data/RAMAYANA.pdf', 'file_path': 'data/RAMAYANA.pdf', 'total_pages': 45, 'format': 'PDF 1.5', 'title': 'RAMAYANA FOR CHILDREN', 'author': 'Sony', 'subject': 'Compiled by', 'keywords': '', 'moddate': '2013-04-14T19:39:50-07:00', 'trapped': '', 'modDate': "D:20130414193950-07'00'", 'creationDate': "D:20130414193950-07'00'", 'page': 12}
# 13
#
# I can fetch you fruits and water and look after you and my respected
# sister-in-law. “So saying, he went to his mother to break the news to
# her.
# Sita, Rama and Lakshmana discarded all their ro
# {'producer': 'Microsoft® Word 2010', 'creator': 'Microsoft® Word 2010', 'creationdate': '2013-04-14T19:39:50-07:00', 'source': 'data/RAMAYANA.pdf', 'file_path': 'data/RAMAYANA.pdf', 'total_pages': 45, 'format': 'PDF 1.5', 'title': 'RAMAYANA FOR CHILDREN', 'author': 'Sony', 'subject': 'Compiled by', 'keywords': '', 'moddate': '2013-04-14T19:39:50-07:00', 'trapped': '', 'modDate': "D:20130414193950-07'00'", 'creationDate': "D:20130414193950-07'00'", 'page': 13}
# 14
#
# The chariot started moving. The king Dasharatha, wanted to have a
# last look at Rama, seeing this Rama wanted the chariot to move
# faster but the old king ran behind it crying out Rama’s name.
#
# {'producer': 'Microsoft® Word 2010', 'creator': 'Microsoft® Word 2010', 'creationdate': '2013-04-14T19:39:50-07:00', 'source': 'data/RAMAYANA.pdf', 'file_path': 'data/RAMAYANA.pdf', 'total_pages': 45, 'format': 'PDF 1.5', 'title': 'RAMAYANA FOR CHILDREN', 'author': 'Sony', 'subject': 'Compiled by', 'keywords': '', 'moddate': '2013-04-14T19:39:50-07:00', 'trapped': '', 'modDate': "D:20130414193950-07'00'", 'creationDate': "D:20130414193950-07'00'", 'page': 14}
# 15
#
# huge trees grew, how the insects collected the food. In the night,
# they slept on the grassy slopes of a tree and at dawn, started their
# journey again. On the way, they halted at hermitage of B
# {'producer': 'Microsoft® Word 2010', 'creator': 'Microsoft® Word 2010', 'creationdate': '2013-04-14T19:39:50-07:00', 'source': 'data/RAMAYANA.pdf', 'file_path': 'data/RAMAYANA.pdf', 'total_pages': 45, 'format': 'PDF 1.5', 'title': 'RAMAYANA FOR CHILDREN', 'author': 'Sony', 'subject': 'Compiled by', 'keywords': '', 'moddate': '2013-04-14T19:39:50-07:00', 'trapped': '', 'modDate': "D:20130414193950-07'00'", 'creationDate': "D:20130414193950-07'00'", 'page': 15}
# 16
#
# the time he took him to the blind parents, the boy was already dead.
# The grief-stricken father of Sravanakumar cursed Dasahratha “O
# King! You have killed my son and thus separated me from him.
# {'producer': 'Microsoft® Word 2010', 'creator': 'Microsoft® Word 2010', 'creationdate': '2013-04-14T19:39:50-07:00', 'source': 'data/RAMAYANA.pdf', 'file_path': 'data/RAMAYANA.pdf', 'total_pages': 45, 'format': 'PDF 1.5', 'title': 'RAMAYANA FOR CHILDREN', 'author': 'Sony', 'subject': 'Compiled by', 'keywords': '', 'moddate': '2013-04-14T19:39:50-07:00', 'trapped': '', 'modDate': "D:20130414193950-07'00'", 'creationDate': "D:20130414193950-07'00'", 'page': 16}
# 17
#
# Kaikeyi thought that Bharatha would be very pleased to hear that
# she had got him the kingdom of Ayodhya. In a gentle tone she said
# “Son1 Nobody can prevent death. Your father passed away “.
# S
# {'producer': 'Microsoft® Word 2010', 'creator': 'Microsoft® Word 2010', 'creationdate': '2013-04-14T19:39:50-07:00', 'source': 'data/RAMAYANA.pdf', 'file_path': 'data/RAMAYANA.pdf', 'total_pages': 45, 'format': 'PDF 1.5', 'title': 'RAMAYANA FOR CHILDREN', 'author': 'Sony', 'subject': 'Compiled by', 'keywords': '', 'moddate': '2013-04-14T19:39:50-07:00', 'trapped': '', 'modDate': "D:20130414193950-07'00'", 'creationDate': "D:20130414193950-07'00'", 'page': 17}
# 18
#
# Bharatha met the ministers. He offered his salutations to Sage
# Vashishta. On seeing Bharatha, Vashishta made arrangements for
# the funeral of Dasharatha. With a heavy heart, Bharatha performed
# {'producer': 'Microsoft® Word 2010', 'creator': 'Microsoft® Word 2010', 'creationdate': '2013-04-14T19:39:50-07:00', 'source': 'data/RAMAYANA.pdf', 'file_path': 'data/RAMAYANA.pdf', 'total_pages': 45, 'format': 'PDF 1.5', 'title': 'RAMAYANA FOR CHILDREN', 'author': 'Sony', 'subject': 'Compiled by', 'keywords': '', 'moddate': '2013-04-14T19:39:50-07:00', 'trapped': '', 'modDate': "D:20130414193950-07'00'", 'creationDate': "D:20130414193950-07'00'", 'page': 18}
# 19
#
# Rama listened to Lakshmana calmly and said “Lakshmana, you have
# misunderstood Bharatha. He also has a lot of love towards him. He
# probably b has come here to ask me to return to Ayodhya. Don’t
# {'producer': 'Microsoft® Word 2010', 'creator': 'Microsoft® Word 2010', 'creationdate': '2013-04-14T19:39:50-07:00', 'source': 'data/RAMAYANA.pdf', 'file_path': 'data/RAMAYANA.pdf', 'total_pages': 45, 'format': 'PDF 1.5', 'title': 'RAMAYANA FOR CHILDREN', 'author': 'Sony', 'subject': 'Compiled by', 'keywords': '', 'moddate': '2013-04-14T19:39:50-07:00', 'trapped': '', 'modDate': "D:20130414193950-07'00'", 'creationDate': "D:20130414193950-07'00'", 'page': 19}
# 20
#
# knowledge of your ministers with you. And the responsibility of
# ruling over Ayodhya is yours. Go back and rule over it well.”
# With no other option Bharatha said “Brother, I will rule over
# Ayo
# {'producer': 'Microsoft® Word 2010', 'creator': 'Microsoft® Word 2010', 'creationdate': '2013-04-14T19:39:50-07:00', 'source': 'data/RAMAYANA.pdf', 'file_path': 'data/RAMAYANA.pdf', 'total_pages': 45, 'format': 'PDF 1.5', 'title': 'RAMAYANA FOR CHILDREN', 'author': 'Sony', 'subject': 'Compiled by', 'keywords': '', 'moddate': '2013-04-14T19:39:50-07:00', 'trapped': '', 'modDate': "D:20130414193950-07'00'", 'creationDate': "D:20130414193950-07'00'", 'page': 20}
# 21
#
# A thatched hut was specially erected for them. Happy and contented,
# Rama decided to spend the night there.*
#
# Rama smiled and replied "Surpanaka, I am already married. Do you
# see the beautifu
# {'producer': 'Microsoft® Word 2010', 'creator': 'Microsoft® Word 2010', 'creationdate': '2013-04-14T19:39:50-07:00', 'source': 'data/RAMAYANA.pdf', 'file_path': 'data/RAMAYANA.pdf', 'total_pages': 45, 'format': 'PDF 1.5', 'title': 'RAMAYANA FOR CHILDREN', 'author': 'Sony', 'subject': 'Compiled by', 'keywords': '', 'moddate': '2013-04-14T19:39:50-07:00', 'trapped': '', 'modDate': "D:20130414193950-07'00'", 'creationDate': "D:20130414193950-07'00'", 'page': 21}
# 22
#
# Dushana. So did Lakshmana.
#
# Surpanaka who also witnessed the mighty power of Rama fled to
# Lanka. When she reached the court of Ravana, he was conducting a
# meeting with his ministers about an
# {'producer': 'Microsoft® Word 2010', 'creator': 'Microsoft® Word 2010', 'creationdate': '2013-04-14T19:39:50-07:00', 'source': 'data/RAMAYANA.pdf', 'file_path': 'data/RAMAYANA.pdf', 'total_pages': 45, 'format': 'PDF 1.5', 'title': 'RAMAYANA FOR CHILDREN', 'author': 'Sony', 'subject': 'Compiled by', 'keywords': '', 'moddate': '2013-04-14T19:39:50-07:00', 'trapped': '', 'modDate': "D:20130414193950-07'00'", 'creationDate': "D:20130414193950-07'00'", 'page': 22}
# 23
#
# “Ha… Ha….” Laughed Ravana scornfully. “How can an ordinary man
# like Rama cause my death? I live across the ocean and he cannot
# even reach me there.”
# “I am warning you Maricha” he continued. “
# {'producer': 'Microsoft® Word 2010', 'creator': 'Microsoft® Word 2010', 'creationdate': '2013-04-14T19:39:50-07:00', 'source': 'data/RAMAYANA.pdf', 'file_path': 'data/RAMAYANA.pdf', 'total_pages': 45, 'format': 'PDF 1.5', 'title': 'RAMAYANA FOR CHILDREN', 'author': 'Sony', 'subject': 'Compiled by', 'keywords': '', 'moddate': '2013-04-14T19:39:50-07:00', 'trapped': '', 'modDate': "D:20130414193950-07'00'", 'creationDate': "D:20130414193950-07'00'", 'page': 23}
# 24
#
# When Maricha’s cry reached Sita’s ears, she felt scared and told
# Lakshmana “Your brother is in danger. Please go to his rescue.”
# Lakshmana tried to calm her by assuring that no harm could ever
# {'producer': 'Microsoft® Word 2010', 'creator': 'Microsoft® Word 2010', 'creationdate': '2013-04-14T19:39:50-07:00', 'source': 'data/RAMAYANA.pdf', 'file_path': 'data/RAMAYANA.pdf', 'total_pages': 45, 'format': 'PDF 1.5', 'title': 'RAMAYANA FOR CHILDREN', 'author': 'Sony', 'subject': 'Compiled by', 'keywords': '', 'moddate': '2013-04-14T19:39:50-07:00', 'trapped': '', 'modDate': "D:20130414193950-07'00'", 'creationDate': "D:20130414193950-07'00'", 'page': 24}
# 25
#
# to my kingdom. Forgot about Rama, who cannot even feed you well
# in this forest. I will treat you like a queen and give you all the
# luxuries of life.
# Sita was very angry at such indecent talk.
# {'producer': 'Microsoft® Word 2010', 'creator': 'Microsoft® Word 2010', 'creationdate': '2013-04-14T19:39:50-07:00', 'source': 'data/RAMAYANA.pdf', 'file_path': 'data/RAMAYANA.pdf', 'total_pages': 45, 'format': 'PDF 1.5', 'title': 'RAMAYANA FOR CHILDREN', 'author': 'Sony', 'subject': 'Compiled by', 'keywords': '', 'moddate': '2013-04-14T19:39:50-07:00', 'trapped': '', 'modDate': "D:20130414193950-07'00'", 'creationDate': "D:20130414193950-07'00'", 'page': 25}
# 26
#
# words had any effect on Ravana. He was mighty pleased with
# himself that he was about to enjoy Sita’s company.
# Feeling desperate, Sita looked down and noticed a group of monkey
# men sitting ato
# {'producer': 'Microsoft® Word 2010', 'creator': 'Microsoft® Word 2010', 'creationdate': '2013-04-14T19:39:50-07:00', 'source': 'data/RAMAYANA.pdf', 'file_path': 'data/RAMAYANA.pdf', 'total_pages': 45, 'format': 'PDF 1.5', 'title': 'RAMAYANA FOR CHILDREN', 'author': 'Sony', 'subject': 'Compiled by', 'keywords': '', 'moddate': '2013-04-14T19:39:50-07:00', 'trapped': '', 'modDate': "D:20130414193950-07'00'", 'creationDate': "D:20130414193950-07'00'", 'page': 26}
# 27
#
# hurried back to Panchavati but were shocked to find it empty. They
# searched and searched for her. Rama went to the Godavari bank but
# could not find her there.
# Rama was heart-broken. Life see
# {'producer': 'Microsoft® Word 2010', 'creator': 'Microsoft® Word 2010', 'creationdate': '2013-04-14T19:39:50-07:00', 'source': 'data/RAMAYANA.pdf', 'file_path': 'data/RAMAYANA.pdf', 'total_pages': 45, 'format': 'PDF 1.5', 'title': 'RAMAYANA FOR CHILDREN', 'author': 'Sony', 'subject': 'Compiled by', 'keywords': '', 'moddate': '2013-04-14T19:39:50-07:00', 'trapped': '', 'modDate': "D:20130414193950-07'00'", 'creationDate': "D:20130414193950-07'00'", 'page': 27}
# 28
#
# Kabandha was once very handsome. But he would turn himself into a
# terrifying creature just to scare the Rishi cursed him “May this
# hideous from stay! Only Rama comes to this forest and chops y
# {'producer': 'Microsoft® Word 2010', 'creator': 'Microsoft® Word 2010', 'creationdate': '2013-04-14T19:39:50-07:00', 'source': 'data/RAMAYANA.pdf', 'file_path': 'data/RAMAYANA.pdf', 'total_pages': 45, 'format': 'PDF 1.5', 'title': 'RAMAYANA FOR CHILDREN', 'author': 'Sony', 'subject': 'Compiled by', 'keywords': '', 'moddate': '2013-04-14T19:39:50-07:00', 'trapped': '', 'modDate': "D:20130414193950-07'00'", 'creationDate': "D:20130414193950-07'00'", 'page': 28}
# 29
#
# against a demon and chased him into a cave, before entering he
# asked Sugriva to stand guard at its entrance. Sugriva waited there
# patiently but since Vali did not come out for many days, he wa
# {'producer': 'Microsoft® Word 2010', 'creator': 'Microsoft® Word 2010', 'creationdate': '2013-04-14T19:39:50-07:00', 'source': 'data/RAMAYANA.pdf', 'file_path': 'data/RAMAYANA.pdf', 'total_pages': 45, 'format': 'PDF 1.5', 'title': 'RAMAYANA FOR CHILDREN', 'author': 'Sony', 'subject': 'Compiled by', 'keywords': '', 'moddate': '2013-04-14T19:39:50-07:00', 'trapped': '', 'modDate': "D:20130414193950-07'00'", 'creationDate': "D:20130414193950-07'00'", 'page': 29}
# 30
#
# As soon as Rama saw the ornaments, tears welled up in his eyes and
# crying out Sita’s name, he fainted. After a while he regained
# consciousness and asked Lakshmana “Brother, please make sure
# t
# {'producer': 'Microsoft® Word 2010', 'creator': 'Microsoft® Word 2010', 'creationdate': '2013-04-14T19:39:50-07:00', 'source': 'data/RAMAYANA.pdf', 'file_path': 'data/RAMAYANA.pdf', 'total_pages': 45, 'format': 'PDF 1.5', 'title': 'RAMAYANA FOR CHILDREN', 'author': 'Sony', 'subject': 'Compiled by', 'keywords': '', 'moddate': '2013-04-14T19:39:50-07:00', 'trapped': '', 'modDate': "D:20130414193950-07'00'", 'creationDate': "D:20130414193950-07'00'", 'page': 30}
# 31
#
# Rama. Without any reason you have killed me. What you have done
# is wrong?”
# In reply Rama said “Vali, Sugriva is my friend. In fact, he is like a
# brother to me. You had forcibly taken away his
# {'producer': 'Microsoft® Word 2010', 'creator': 'Microsoft® Word 2010', 'creationdate': '2013-04-14T19:39:50-07:00', 'source': 'data/RAMAYANA.pdf', 'file_path': 'data/RAMAYANA.pdf', 'total_pages': 45, 'format': 'PDF 1.5', 'title': 'RAMAYANA FOR CHILDREN', 'author': 'Sony', 'subject': 'Compiled by', 'keywords': '', 'moddate': '2013-04-14T19:39:50-07:00', 'trapped': '', 'modDate': "D:20130414193950-07'00'", 'creationDate': "D:20130414193950-07'00'", 'page': 31}
# 32
#
# dared to go to Sugriva for he had warned them not to come back
# without news about Sita. As they were unsuccessful in their aim,
# they decided they would rather die. “Yes! Let us end our lives.
# {'producer': 'Microsoft® Word 2010', 'creator': 'Microsoft® Word 2010', 'creationdate': '2013-04-14T19:39:50-07:00', 'source': 'data/RAMAYANA.pdf', 'file_path': 'data/RAMAYANA.pdf', 'total_pages': 45, 'format': 'PDF 1.5', 'title': 'RAMAYANA FOR CHILDREN', 'author': 'Sony', 'subject': 'Compiled by', 'keywords': '', 'moddate': '2013-04-14T19:39:50-07:00', 'trapped': '', 'modDate': "D:20130414193950-07'00'", 'creationDate': "D:20130414193950-07'00'", 'page': 32}
# 33
#
# 1.9 Hanuman meets Sita- Lanka is destroyed
# Hanuman was also applauded by Suras who showered flower petals
# on him. The Sun God silently blessed Hanuman by radiating less of
# heat. The wind God
# {'producer': 'Microsoft® Word 2010', 'creator': 'Microsoft® Word 2010', 'creationdate': '2013-04-14T19:39:50-07:00', 'source': 'data/RAMAYANA.pdf', 'file_path': 'data/RAMAYANA.pdf', 'total_pages': 45, 'format': 'PDF 1.5', 'title': 'RAMAYANA FOR CHILDREN', 'author': 'Sony', 'subject': 'Compiled by', 'keywords': '', 'moddate': '2013-04-14T19:39:50-07:00', 'trapped': '', 'modDate': "D:20130414193950-07'00'", 'creationDate': "D:20130414193950-07'00'", 'page': 33}
# 34
#
# would die. This would lead to Lakshmana’s death too. Unable to bear
# the news, Bharatha, Shatrugna, Kaushalya ….. and the entire
# Ayodhya will die mourning for Rama. Sugriva will end his life un
# {'producer': 'Microsoft® Word 2010', 'creator': 'Microsoft® Word 2010', 'creationdate': '2013-04-14T19:39:50-07:00', 'source': 'data/RAMAYANA.pdf', 'file_path': 'data/RAMAYANA.pdf', 'total_pages': 45, 'format': 'PDF 1.5', 'title': 'RAMAYANA FOR CHILDREN', 'author': 'Sony', 'subject': 'Compiled by', 'keywords': '', 'moddate': '2013-04-14T19:39:50-07:00', 'trapped': '', 'modDate': "D:20130414193950-07'00'", 'creationDate': "D:20130414193950-07'00'", 'page': 34}
# 35
#
# soon as she saw her husband’s ring. She could then believe
# Hanuman when he told her that Rama would soon be waging a war
# against Ravana and rescue her from Lanka. She gave Hanuman one
# of her
# {'producer': 'Microsoft® Word 2010', 'creator': 'Microsoft® Word 2010', 'creationdate': '2013-04-14T19:39:50-07:00', 'source': 'data/RAMAYANA.pdf', 'file_path': 'data/RAMAYANA.pdf', 'total_pages': 45, 'format': 'PDF 1.5', 'title': 'RAMAYANA FOR CHILDREN', 'author': 'Sony', 'subject': 'Compiled by', 'keywords': '', 'moddate': '2013-04-14T19:39:50-07:00', 'trapped': '', 'modDate': "D:20130414193950-07'00'", 'creationDate': "D:20130414193950-07'00'", 'page': 35}
# 36
#
# Ravana was very angry “How dare a monkey talk to a king like me in
# such a way” he thundered. He ordered his soldiers “Kill this arrogant
# Vanara.” But Vibhishana, his brother, stopped him. “Bro
# {'producer': 'Microsoft® Word 2010', 'creator': 'Microsoft® Word 2010', 'creationdate': '2013-04-14T19:39:50-07:00', 'source': 'data/RAMAYANA.pdf', 'file_path': 'data/RAMAYANA.pdf', 'total_pages': 45, 'format': 'PDF 1.5', 'title': 'RAMAYANA FOR CHILDREN', 'author': 'Sony', 'subject': 'Compiled by', 'keywords': '', 'moddate': '2013-04-14T19:39:50-07:00', 'trapped': '', 'modDate': "D:20130414193950-07'00'", 'creationDate': "D:20130414193950-07'00'", 'page': 36}
# 37
#
# among us who is capable of flying across the ocean. So, Please tell
# us how we can get there.” Rama also asked his trusted friend about
# Lanka’s city plan, about its main gates, about trenches b
# {'producer': 'Microsoft® Word 2010', 'creator': 'Microsoft® Word 2010', 'creationdate': '2013-04-14T19:39:50-07:00', 'source': 'data/RAMAYANA.pdf', 'file_path': 'data/RAMAYANA.pdf', 'total_pages': 45, 'format': 'PDF 1.5', 'title': 'RAMAYANA FOR CHILDREN', 'author': 'Sony', 'subject': 'Compiled by', 'keywords': '', 'moddate': '2013-04-14T19:39:50-07:00', 'trapped': '', 'modDate': "D:20130414193950-07'00'", 'creationDate': "D:20130414193950-07'00'", 'page': 37}
# 38
#
# again. Just that day, he had finished one round of sleeping. Though
# he did not like Ravenna’s behavior, he decided to support him out of
# brotherly love and loyalty.
# Vibhishana could not toler
# {'producer': 'Microsoft® Word 2010', 'creator': 'Microsoft® Word 2010', 'creationdate': '2013-04-14T19:39:50-07:00', 'source': 'data/RAMAYANA.pdf', 'file_path': 'data/RAMAYANA.pdf', 'total_pages': 45, 'format': 'PDF 1.5', 'title': 'RAMAYANA FOR CHILDREN', 'author': 'Sony', 'subject': 'Compiled by', 'keywords': '', 'moddate': '2013-04-14T19:39:50-07:00', 'trapped': '', 'modDate': "D:20130414193950-07'00'", 'creationDate': "D:20130414193950-07'00'", 'page': 38}
# 39
#
# Rama agreed with Hanuman and said “It is my duty to protect those
# who seek refuge in me “. On hearing these words, Vibhishana fell at
# Rama’s feet and thanked him for this gesture.
# Sri Rama em
# {'producer': 'Microsoft® Word 2010', 'creator': 'Microsoft® Word 2010', 'creationdate': '2013-04-14T19:39:50-07:00', 'source': 'data/RAMAYANA.pdf', 'file_path': 'data/RAMAYANA.pdf', 'total_pages': 45, 'format': 'PDF 1.5', 'title': 'RAMAYANA FOR CHILDREN', 'author': 'Sony', 'subject': 'Compiled by', 'keywords': '', 'moddate': '2013-04-14T19:39:50-07:00', 'trapped': '', 'modDate': "D:20130414193950-07'00'", 'creationDate': "D:20130414193950-07'00'", 'page': 39}
# 40
#
# was conveyed to Sita and she was brought in flying-machine to show
# her the fate of her husband and her brother-in-law. She was grief
# stricken that her dearest husband was dead.
# Soon, the whol
# {'producer': 'Microsoft® Word 2010', 'creator': 'Microsoft® Word 2010', 'creationdate': '2013-04-14T19:39:50-07:00', 'source': 'data/RAMAYANA.pdf', 'file_path': 'data/RAMAYANA.pdf', 'total_pages': 45, 'format': 'PDF 1.5', 'title': 'RAMAYANA FOR CHILDREN', 'author': 'Sony', 'subject': 'Compiled by', 'keywords': '', 'moddate': '2013-04-14T19:39:50-07:00', 'trapped': '', 'modDate': "D:20130414193950-07'00'", 'creationDate': "D:20130414193950-07'00'", 'page': 40}
# 41
#
# Naranthaka, Trishiraska and Atikaya to the battle. But they were no
# match for the Vanaras and soon Ravana received news about their
# deaths too.
# Ravana was terribly shaken by these losses. Gri
# {'producer': 'Microsoft® Word 2010', 'creator': 'Microsoft® Word 2010', 'creationdate': '2013-04-14T19:39:50-07:00', 'source': 'data/RAMAYANA.pdf', 'file_path': 'data/RAMAYANA.pdf', 'total_pages': 45, 'format': 'PDF 1.5', 'title': 'RAMAYANA FOR CHILDREN', 'author': 'Sony', 'subject': 'Compiled by', 'keywords': '', 'moddate': '2013-04-14T19:39:50-07:00', 'trapped': '', 'modDate': "D:20130414193950-07'00'", 'creationDate': "D:20130414193950-07'00'", 'page': 41}
# 42
#
# Inderjit’s death was the severest blow to Ravana. He had lost all his
# sons, his brothers and his army in the war. The whole of Lanka
# plunged into sorrow. Some criticized Surpanaka for provokin
# {'producer': 'Microsoft® Word 2010', 'creator': 'Microsoft® Word 2010', 'creationdate': '2013-04-14T19:39:50-07:00', 'source': 'data/RAMAYANA.pdf', 'file_path': 'data/RAMAYANA.pdf', 'total_pages': 45, 'format': 'PDF 1.5', 'title': 'RAMAYANA FOR CHILDREN', 'author': 'Sony', 'subject': 'Compiled by', 'keywords': '', 'moddate': '2013-04-14T19:39:50-07:00', 'trapped': '', 'modDate': "D:20130414193950-07'00'", 'creationDate': "D:20130414193950-07'00'", 'page': 42}
# 43
#
# Sri Rama then sent Hanuman to fetch Sita. Sitadevi was very happy
# that at least the wicked Ravana had been killed. She looked forward
# to rejoin her beloved Rama. But he did not accept her imme
# {'producer': 'Microsoft® Word 2010', 'creator': 'Microsoft® Word 2010', 'creationdate': '2013-04-14T19:39:50-07:00', 'source': 'data/RAMAYANA.pdf', 'file_path': 'data/RAMAYANA.pdf', 'total_pages': 45, 'format': 'PDF 1.5', 'title': 'RAMAYANA FOR CHILDREN', 'author': 'Sony', 'subject': 'Compiled by', 'keywords': '', 'moddate': '2013-04-14T19:39:50-07:00', 'trapped': '', 'modDate': "D:20130414193950-07'00'", 'creationDate': "D:20130414193950-07'00'", 'page': 43}
# 44
#
# Vashishta blessed Rama and with their consent, Rama agreed to
# become the king.
# Soon Rama was crowned the king of Ayodhya. The coronation was
# conducted on a grand scale, Rama and Sita were sea
# {'producer': 'Microsoft® Word 2010', 'creator': 'Microsoft® Word 2010', 'creationdate': '2013-04-14T19:39:50-07:00', 'source': 'data/RAMAYANA.pdf', 'file_path': 'data/RAMAYANA.pdf', 'total_pages': 45, 'format': 'PDF 1.5', 'title': 'RAMAYANA FOR CHILDREN', 'author': 'Sony', 'subject': 'Compiled by', 'keywords': '', 'moddate': '2013-04-14T19:39:50-07:00', 'trapped': '', 'modDate': "D:20130414193950-07'00'", 'creationDate': "D:20130414193950-07'00'", 'page': 44}

# %% [markdown]
# #Data Chunking

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter

# Split the documents into smaller chunks
splitter = RecursiveCharacterTextSplitter(
    chunk_size=300,
    chunk_overlap=50,
    separators=["\n\n", "\n", ".", " "] # we can use custom separators 
)
chunks = splitter.split_documents(docs)

# %% [markdown]
# # Data Embedding
# ## OpenAI

# %%
# Read key from file (or load from env manually)
with open("data/key.txt", "r") as f:
    api_key = f.read().strip()

# Create embeddings for the chunks
from langchain.embeddings import OpenAIEmbeddings
embedding_model = OpenAIEmbeddings(
    model="text-embedding-3-small",
    openai_api_key=api_key
)
vectors = embedding_model.embed_documents([chunk.page_content for chunk in chunks[0:3]])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 2
#       1 # Read key from file (or load from env manually)
# ----> 2 with open("data/key.txt", "r") as f:
#       3     api_key = f.read().strip()
#       5 # Create embeddings for the chunks
#
# File d:\Visual Studio Code\AI_Classes_Aifalabs\.venv\lib\site-packages\IPython\core\interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/key.txt'

# %%
# Check the number of vectors
print(f"Generated {len(vectors)} embedding vectors.")

# Print each vector (or part of it)
for i, vec in enumerate(vectors):
    print(f"\n--- Embedding for Chunk {i+1} (length: {len(vec)}) ---")
    print(vec[:10], "...")  # show only first 10 values for readability
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 # Check the number of vectors
# ----> 2 print(f"Generated {len(vectors)} embedding vectors.")
#       4 # Print each vector (or part of it)
#       5 for i, vec in enumerate(vectors):
#
# NameError: name 'vectors' is not defined

# %% [markdown]
# ## HuggingFace

# %%
from sentence_transformers import SentenceTransformer

model = SentenceTransformer('all-MiniLM-L6-v2', device='cpu')
vectors = model.encode([chunk.page_content for chunk in chunks[0:3]])
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File d:\Visual Studio Code\AI_Classes_Aifalabs\.venv\lib\site-packages\transformers\activations_tf.py:22
#      21 try:
# ---> 22     import tf_keras as keras
#      23 except (ModuleNotFoundError, ImportError):
#
# ModuleNotFoundError: No module named 'tf_keras'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 from sentence_transformers import SentenceTransformer
#       3 model = SentenceTransformer('all-MiniLM-L6-v2', device='cpu')
#       4 vectors = model.encode([chunk.page_content for chunk in chunks[0:3]])
#
# File d:\Visual Studio Code\AI_Classes_Aifalabs\.venv\lib\site-packages\sentence_transformers\__init__.py:14
#       7 import os
#       9 from sentence_transformers.backend import (
#      10     export_dynamic_quantized_onnx_model,
#      11     export_optimized_onnx_model,
#      12     export_static_quantized_openvino_model,
#      13 )
# ---> 14 from sentence_transformers.cross_encoder import (
#      15     CrossEncoder,
#      16     CrossEncoderModelCardData,
#      17     CrossEncoderTrainer,
#      18     CrossEncoderTrainingArguments,
#      19 )
#      20 from sentence_transformers.datasets import ParallelSentencesDataset, SentencesDataset
#      21 from sentence_transformers.LoggingHandler import LoggingHandler
#
# File d:\Visual Studio Code\AI_Classes_Aifalabs\.venv\lib\site-packages\sentence_transformers\cross_encoder\__init__.py:3
#       1 from __future__ import annotations
# ----> 3 from .CrossEncoder import CrossEncoder
#       4 from .model_card import CrossEncoderModelCardData
#       5 from .trainer import CrossEncoderTrainer
#
# File d:\Visual Studio Code\AI_Classes_Aifalabs\.venv\lib\site-packages\sentence_transformers\cross_encoder\CrossEncoder.py:31
#      28 from typing_extensions import deprecated
#      30 from sentence_transformers import __version__
# ---> 31 from sentence_transformers.cross_encoder.fit_mixin import FitMixin
#      32 from sentence_transformers.cross_encoder.model_card import CrossEncoderModelCardData, generate_model_card
#      33 from sentence_transformers.cross_encoder.util import (
#      34     cross_encoder_init_args_decorator,
#      35     cross_encoder_predict_rank_args_decorator,
#      36 )
#
# File d:\Visual Studio Code\AI_Classes_Aifalabs\.venv\lib\site-packages\sentence_transformers\cross_encoder\fit_mixin.py:20
#      18 from sentence_transformers.cross_encoder.training_args import CrossEncoderTrainingArguments
#      19 from sentence_transformers.datasets.NoDuplicatesDataLoader import NoDuplicatesDataLoader
# ---> 20 from sentence_transformers.datasets.SentenceLabelDataset import SentenceLabelDataset
#      21 from sentence_transformers.evaluation.SentenceEvaluator import SentenceEvaluator
#      22 from sentence_transformers.readers import InputExample
#
# File d:\Visual Studio Code\AI_Classes_Aifalabs\.venv\lib\site-packages\sentence_transformers\datasets\__init__.py:13
#      11 from .DenoisingAutoEncoderDataset import DenoisingAutoEncoderDataset
#      12 from .NoDuplicatesDataLoader import NoDuplicatesDataLoader
# ---> 13 from .ParallelSentencesDataset import ParallelSentencesDataset
#      14 from .SentenceLabelDataset import SentenceLabelDataset
#      15 from .SentencesDataset import SentencesDataset
#
# File d:\Visual Studio Code\AI_Classes_Aifalabs\.venv\lib\site-packages\sentence_transformers\datasets\ParallelSentencesDataset.py:19
#      15 import random
#      17 from torch.utils.data import Dataset
# ---> 19 from sentence_transformers import SentenceTransformer
#      20 from sentence_transformers.readers import InputExample
#      22 logger = logging.getLogger(__name__)
#
# File d:\Visual Studio Code\AI_Classes_Aifalabs\.venv\lib\site-packages\sentence_transformers\SentenceTransformer.py:34
#      31 from transformers import is_torch_npu_available
#      32 from transformers.dynamic_module_utils import get_class_from_dynamic_module, get_relative_import_files
# ---> 34 from sentence_transformers.model_card import SentenceTransformerModelCardData, generate_model_card
#      35 from sentence_transformers.similarity_functions import SimilarityFunction
#      37 from . import __MODEL_HUB_ORGANIZATION__, __version__
#
# File d:\Visual Studio Code\AI_Classes_Aifalabs\.venv\lib\site-packages\sentence_transformers\model_card.py:25
#      23 from tqdm.autonotebook import tqdm
#      24 from transformers import TrainerCallback
# ---> 25 from transformers.integrations import CodeCarbonCallback
#      26 from transformers.modelcard import make_markdown_table
#      27 from transformers.trainer_callback import TrainerControl, TrainerState
#
# File <frozen importlib._bootstrap>:1075, in _handle_fromlist(module, fromlist, import_, recursive)
#
# File d:\Visual Studio Code\AI_Classes_Aifalabs\.venv\lib\site-packages\transformers\utils\import_utils.py:2045, in _LazyModule.__getattr__(self, name)
#    2043 elif name in self._class_to_module.keys():
#    2044     try:
# -> 2045         module = self._get_module(self._class_to_module[name])
#    2046         value = getattr(module, name)
#    2047     except (ModuleNotFoundError, RuntimeError) as e:
#
# File d:\Visual Studio Code\AI_Classes_Aifalabs\.venv\lib\site-packages\transformers\utils\import_utils.py:2075, in _LazyModule._get_module(self, module_name)
#    2073     return importlib.import_module("." + module_name, self.__name__)
#    2074 except Exception as e:
# -> 2075     raise e
#
# File d:\Visual Studio Code\AI_Classes_Aifalabs\.venv\lib\site-packages\transformers\utils\import_utils.py:2073, in _LazyModule._get_module(self, module_name)
#    2071 def _get_module(self, module_name: str):
#    2072     try:
# -> 2073         return importlib.import_module("." + module_name, self.__name__)
#    2074     except Exception as e:
#    2075         raise e
#
# File C:\Program Files\Python310\lib\importlib\__init__.py:126, in import_module(name, package)
#     124             break
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File d:\Visual Studio Code\AI_Classes_Aifalabs\.venv\lib\site-packages\transformers\integrations\integration_utils.py:37
#      34 import numpy as np
#      35 import packaging.version
# ---> 37 from .. import PreTrainedModel, TFPreTrainedModel, TrainingArguments
#      38 from .. import __version__ as version
#      39 from ..utils import (
#      40     PushToHubMixin,
#      41     flatten_dict,
#    (...)
#      46     logging,
#      47 )
#
# File <frozen importlib._bootstrap>:1075, in _handle_fromlist(module, fromlist, import_, recursive)
#
# File d:\Visual Studio Code\AI_Classes_Aifalabs\.venv\lib\site-packages\transformers\utils\import_utils.py:2045, in _LazyModule.__getattr__(self, name)
#    2043 elif name in self._class_to_module.keys():
#    2044     try:
# -> 2045         module = self._get_module(self._class_to_module[name])
#    2046         value = getattr(module, name)
#    2047     except (ModuleNotFoundError, RuntimeError) as e:
#
# File d:\Visual Studio Code\AI_Classes_Aifalabs\.venv\lib\site-packages\transformers\utils\import_utils.py:2075, in _LazyModule._get_module(self, module_name)
#    2073     return importlib.import_module("." + module_name, self.__name__)
#    2074 except Exception as e:
# -> 2075     raise e
#
# File d:\Visual Studio Code\AI_Classes_Aifalabs\.venv\lib\site-packages\transformers\utils\import_utils.py:2073, in _LazyModule._get_module(self, module_name)
#    2071 def _get_module(self, module_name: str):
#    2072     try:
# -> 2073         return importlib.import_module("." + module_name, self.__name__)
#    2074     except Exception as e:
#    2075         raise e
#
# File C:\Program Files\Python310\lib\importlib\__init__.py:126, in import_module(name, package)
#     124             break
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File d:\Visual Studio Code\AI_Classes_Aifalabs\.venv\lib\site-packages\transformers\modeling_tf_utils.py:38
#      35 from packaging.version import parse
#      37 from . import DataCollatorWithPadding, DefaultDataCollator
# ---> 38 from .activations_tf import get_tf_activation
#      39 from .configuration_utils import PretrainedConfig
#      40 from .dynamic_module_utils import custom_object_save
#
# File d:\Visual Studio Code\AI_Classes_Aifalabs\.venv\lib\site-packages\transformers\activations_tf.py:27
#      24     import keras
#      26     if parse(keras.__version__).major > 2:
# ---> 27         raise ValueError(
#      28             "Your currently installed version of Keras is Keras 3, but this is not yet supported in "
#      29             "Transformers. Please install the backwards-compatible tf-keras package with "
#      30             "`pip install tf-keras`."
#      31         )
#      34 def _gelu(x):
#      35     """
#      36     Gaussian Error Linear Unit. Original Implementation of the gelu activation function in Google Bert repo when
#      37     initially created. For information: OpenAI GPT's gelu is slightly different (and gives slightly different results):
#      38     0.5 * x * (1 + torch.tanh(math.sqrt(2 / math.pi) * (x + 0.044715 * torch.pow(x, 3)))) Also see
#      39     https://arxiv.org/abs/1606.08415
#      40     """
#
# ValueError: Your currently installed version of Keras is Keras 3, but this is not yet supported in Transformers. Please install the backwards-compatible tf-keras package with `pip install tf-keras`.

# %%
# Check the number of vectors
print(f"Generated {len(vectors)} embedding vectors.")

# Print each vector (or part of it)
for i, vec in enumerate(vectors):
    print(f"\n--- Embedding for Chunk {i+1} (length: {len(vec)}) ---")
    print(vec[:10], "...")  # show only first 10 values for readability
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 2
#       1 # Check the number of vectors
# ----> 2 print(f"Generated {len(vectors)} embedding vectors.")
#       4 # Print each vector (or part of it)
#       5 for i, vec in enumerate(vectors):
#
# NameError: name 'vectors' is not defined

# %%
from langchain.schema import Document
documents = [
    Document(page_content="AI enables automation of complex tasks.", metadata={"title": "Introduction to AI"}),
    Document(page_content="LLMs are used in chatbots and assistants.", metadata={"title": "Applications of LLMs"})
]
# This metadata can be used later to boost or filter during retrieval
print(documents[0].metadata['title'])  # Output: Introduction to AI
# Out:
# Introduction to AI
